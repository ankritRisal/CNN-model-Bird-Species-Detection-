# %%
import os
import numpy as np
import torch
import glob  ## finds all the pathnames matching a specified pattern
import torch.nn as nn   # helps build neural network models
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.autograd import Variable   ## for automatic differentiation that performs back propagation
import torchvision
import pathlib   #  provides various classes representing file system paths with semantics appropriate for different operating systems

# %%
model_dir = '/Users/risal/My_Codes/Projectdataminor/traintestsplit'
os.chdir(model_dir)

# %%
# check whcih  device to train is available
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device , "is available")
torch.cuda.empty_cache()
# Out:
# cuda is available

# %%
trnsfrm=transforms.Compose([
    transforms.Resize((150,150)),
    transforms.RandomHorizontalFlip(),
    # added --
    transforms.RandomRotation(degrees=15),
    transforms.RandomResizedCrop(150, scale=(0.8, 1.0), ratio=(0.75, 1.333)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
   #--
    transforms.ToTensor(),  # conversion of  numpy to tensors, since pytorch processes data in tensors
    transforms.Normalize([0.5,0.5,0.5], # normalize using mean and standard deviation
                        [0.5,0.5,0.5])
])

# %%
## training and testing directory path
# C:\Users\risal\My_Codes\Projectdataminor\traintestsplit\Dataset\train
train_path='/Users/risal/My_Codes/Projectdataminor/traintestsplit/DataSet/train'
# val_path='/Users/risal/My_Codes/Projectdataminor/CrossValidation/birdsDataSet/Dataset/val'

# %%
# Pytorch  Dataloader

full_data_loader=DataLoader(
    torchvision.datasets.ImageFolder(train_path,transform=trnsfrm),
    batch_size=32, shuffle=True
)

# %%
import torch
from torchvision import datasets

# Load the dataset without normalization

data = next(iter(full_data_loader))
images, _ = data
mean = torch.mean(images, dim=(0, 2, 3))
std = torch.std(images, dim=(0, 2, 3))

print("Mean:", mean)
print("Std:", std)
# Out:
# Mean: tensor([-0.0790, -0.1079, -0.2739])
# Std: tensor([0.4986, 0.4682, 0.4872])

# %%
#categories
root=pathlib.Path(train_path)
classes=sorted([j.name.split('/')[-1] for j in root.iterdir()])
# Add unique labels to the classes
class_labels = {label: i for i, label in enumerate(classes)}

# Print the class labels
print(class_labels)
# print(classes)
# Out:
# {'Abbott’s Babbler Malacocincla abbotti': 0, 'Black Bittern (Dupetor flavicollis)': 1, 'Blue-eared Kingfisher Alcedo meninting': 2, 'Blue-naped Pitta Pitta nipalensis': 3, 'Broad-billed Warbler Tickellia hodgsoni': 4, 'Cheer Pheasant (Catreus wallichii)': 5, 'Chestnut Munia Lonchura atricapilla': 6, 'Cinereous Vulture Aegypius monachus': 7, 'Golden Babbler Stachyris chrysaea': 8, 'Gould’s Shortwing Brachypteryx stellata': 9, 'Great Bittern Botaurus stellaris': 10, 'Great Hornbill (Buceros bicornis)': 11, 'Great Slaty Woodpecker Mulleripicus pulverulentus': 12, 'Ibisbill Ibidorhyncha struthersii': 13, 'Indian Courser Cursorius coromandelicus': 14, 'Indian Grassbird - Graminicola bengalensis': 15, 'Indian Nightjar Caprimulgus asiaticus': 16, 'Knob-billed Duck Sarkidiornis melanotos': 17, 'Northern Pintail Anas acuta': 18, 'Painted Stork Mycteria leucocephala': 19, 'Purple Cochoa Cochoa purpurea': 20, 'Red-headed Trogon Harpactes erythrocephalus': 21, 'Red-headed Vulture Sarcogyps calvus': 22, 'Red-necked Falcon Falco chicquera': 23, 'Ruby-cheeked Sunbird Anthreptes singalensis': 24, 'Rusty-fronted Barwing Actinodura egertoni': 25, 'Saker Falcon Falco cherrug': 26, 'Silver-eared Mesia Leiothrix argentauris': 27, 'Slaty-legged Crake Rallina eurizonoides': 28, 'Spot-bellied Eagle Owl Bubo nipalensis': 29, 'Sultan Tit Melanochlora sultanea': 30, 'Swamp Francolin Francolinus gularis': 31, 'Tawny-bellied Babbler Dumetia hyperythra': 32, 'Thick-billed Green Pigeon Treron curvirostra': 33, 'White-throated Bulbul Alophoixus flaveolus': 34, 'White-throated Bushchat Saxicola insignis': 35, 'Yellow-rumped Honeyguide - Indicator xanthonotus': 36, 'Yellow-vented Warbler Phylloscopus cantator': 37}

# %%
# import torch.nn as nn

# class ConvNet(nn.Module):
#     def __init__(self, num_classes=38, kernel_size_conv1=3, in_channels=3,
#                  out_channels_conv1=12, out_channels_conv2=20, kernel_size_conv2=3,
#                  out_channels_conv3=32, kernel_size_conv3=3, num_features_batchnorm=32,
#                  kernel_size_maxpool=2, dropout_prob=0.3):
#         super(ConvNet, self).__init__()

#         # Convolutional layers
#         self.conv1 = nn.Conv2d(in_channels=in_channels, out_channels=out_channels_conv1,
#                                kernel_size=kernel_size_conv1, stride=1, padding=1)
#         self.btch1 = nn.BatchNorm2d(num_features=out_channels_conv1)
#         self.relu1 = nn.LeakyReLU()
#         self.pool = nn.MaxPool2d(kernel_size=kernel_size_maxpool)

#         self.conv2 = nn.Conv2d(in_channels=out_channels_conv1, out_channels=out_channels_conv2,
#                                kernel_size=kernel_size_conv2, stride=1, padding=1)
#         self.relu2 = nn.LeakyReLU()
#         self.dropout1 = nn.Dropout(p=dropout_prob)

#         self.conv3 = nn.Conv2d(in_channels=out_channels_conv2, out_channels=out_channels_conv3,
#                                kernel_size=kernel_size_conv3, stride=1, padding=1)
#         self.btch3 = nn.BatchNorm2d(num_features=out_channels_conv3)
#         self.relu3 = nn.LeakyReLU()
#         self.dropout2 = nn.Dropout(p=dropout_prob)  # Regularization drop_out

#         # Fully connected layer
#         self.fc = nn.Linear(in_features=75 * 75 * out_channels_conv3, out_features=num_classes)

#     def forward(self, input):
#         # Convolutional layers
#         ot_put = self.conv1(input)
#         ot_put = self.btch1(ot_put)
#         ot_put = self.relu1(ot_put)
#         ot_put = self.pool(ot_put)

#         ot_put = self.conv2(ot_put)
#         ot_put = self.relu2(ot_put)
#         ot_put = self.dropout1(ot_put)

#         ot_put = self.conv3(ot_put)
#         ot_put = self.btch3(ot_put)
#         ot_put = self.relu3(ot_put)
#         ot_put = self.dropout2(ot_put)

#         # Reshape and fully connected layer
#         ot_put = ot_put.view(-1, 75 * 75 * 32)
#         ot_put = self.fc(ot_put)

#         return ot_put

# %%
import torch.nn as nn

class ConvNet(nn.Module):
    def __init__(self, num_classes=38, kernel_size_conv1=3, in_channels=3,
                 out_channels_conv1=12, out_channels_conv2=20, kernel_size_conv2=3,
                 out_channels_conv3=32, kernel_size_conv3=3, num_features_batchnorm=32,
                 kernel_size_maxpool=2, dropout_prob=0.6):
        super(ConvNet, self).__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(in_channels=in_channels, out_channels=out_channels_conv1,
                               kernel_size=kernel_size_conv1, stride=1, padding=1)
        self.btch1 = nn.BatchNorm2d(num_features=out_channels_conv1)
        self.relu1 = nn.LeakyReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=kernel_size_maxpool)
        self.dropout1 = nn.Dropout(p=dropout_prob)

        self.conv2 = nn.Conv2d(in_channels=out_channels_conv1, out_channels=out_channels_conv2,
                               kernel_size=kernel_size_conv2, stride=1, padding=1)
        self.relu2 = nn.LeakyReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=kernel_size_maxpool)
        self.dropout2 = nn.Dropout(p=dropout_prob)

        self.conv3 = nn.Conv2d(in_channels=out_channels_conv2, out_channels=out_channels_conv3,
                               kernel_size=kernel_size_conv3, stride=1, padding=1)
        self.btch3 = nn.BatchNorm2d(num_features=out_channels_conv3)
        self.relu3 = nn.LeakyReLU()
        self.pool3 = nn.MaxPool2d(kernel_size=kernel_size_maxpool)
        self.dropout3 = nn.Dropout(p=dropout_prob)

        # Fully connected layer
        self.fc = nn.Linear(in_features=18 * 18 * out_channels_conv3, out_features=num_classes)

    def forward(self, input):
        # Convolutional layers
        ot_put = self.conv1(input)
        ot_put = self.btch1(ot_put)
        ot_put = self.relu1(ot_put)
        ot_put = self.pool1(ot_put)
        ot_put = self.dropout1(ot_put)

        ot_put = self.conv2(ot_put)
        ot_put = self.relu2(ot_put)
        ot_put = self.pool2(ot_put)
        ot_put = self.dropout2(ot_put)

        ot_put = self.conv3(ot_put)
        ot_put = self.btch3(ot_put)
        ot_put = self.relu3(ot_put)
        ot_put = self.pool3(ot_put)
        ot_put = self.dropout3(ot_put)

        # Reshape and fully connected layer
        ot_put = ot_put.view(-1, 18 * 18 * 32)
        ot_put = self.fc(ot_put)

        return ot_put

# %%
mdl= ConvNet(num_classes=38).to(device)
optimizer=Adam(mdl.parameters(),lr=0.0001,weight_decay=0.001)
loss_function=nn.CrossEntropyLoss()
num_epochs=10

# %%
# Total size of training and testing images
train_count=len(glob.glob(train_path+'/**/*'))
# val_count=len(glob.glob(val_path+'/**/*'))
print(train_count)# Total size of training and testing images
# Out:
# 8073

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt

# Assuming you have the DataLoader for your entire dataset called 'full_data_loader'

# Number of folds for cross-validation
num_folds = 10

# Initialize StratifiedKFold with the number of folds
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Lists to store accuracy and loss values for each fold
all_train_accuracy = []
all_train_loss = []
all_val_accuracy = []
all_val_loss = []

# Early stopping parameters
early_stop_patience = 3  # Number of epochs without improvement to wait before early stopping
early_stop_counter = 0

best_val_loss = float('inf')

# K-fold Cross-validation loop
for fold, (train_indices, val_indices) in enumerate(skf.split(range(len(full_data_loader.dataset)), full_data_loader.dataset.targets)):
    print(f"\nFold {fold + 1}/{num_folds}")

    # Create data loaders for training and validation using indices from the current fold
    train_loader = torch.utils.data.DataLoader(torch.utils.data.Subset(full_data_loader.dataset, train_indices), batch_size=32, shuffle=True)
    val_loader = torch.utils.data.DataLoader(torch.utils.data.Subset(full_data_loader.dataset, val_indices), batch_size=32, shuffle=False)

    # Training loop
    for epoch in range(num_epochs):
        mdl.train()
        train_accuracy = 0.0
        train_loss = 0.0

        for i, (images, labels) in enumerate(train_loader):
            if torch.cuda.is_available():
                images = Variable(images.cuda())
                labels = Variable(labels.cuda())

            optimizer.zero_grad()

            outputs = mdl(images)
            loss = loss_function(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.cpu().data * images.size(0)
            _, prediction = torch.max(outputs.data, 1)
            train_accuracy += int(torch.sum(prediction == labels.data))

        train_accuracy = train_accuracy / len(train_indices)
        train_loss = train_loss / len(train_indices)

        # Validation loop
        mdl.eval()
        val_accuracy = 0.0
        val_loss = 0.0

        for i, (images, labels) in enumerate(val_loader):
            if torch.cuda.is_available():
                images = Variable(images.cuda())
                labels = Variable(labels.cuda())

            outputs = mdl(images)
            _, prediction = torch.max(outputs.data, 1)
            val_accuracy += int(torch.sum(prediction == labels.data))
            val_loss += loss_function(outputs, labels).cpu().item() * images.size(0)

        val_accuracy = val_accuracy / len(val_indices)
        val_loss = val_loss / len(val_indices)

        print(f'Fold {fold + 1}/{num_folds}, Epoch: {epoch + 1}, Train Loss: {train_loss}, Train Accuracy: {train_accuracy}, Val Accuracy: {val_accuracy}, Val Loss: {val_loss}')

        # Append accuracy and loss values to the lists
        all_train_accuracy.append(train_accuracy)
        all_train_loss.append(train_loss)
        all_val_accuracy.append(val_accuracy)
        all_val_loss.append(val_loss)

        if val_loss < best_val_loss:
            early_stop_counter = 0  # Reset the counter when there's an improvement
            best_val_loss = val_loss
        else:
            early_stop_counter += 1

        if early_stop_counter >= early_stop_patience:
            print(f'Early stopping after {early_stop_patience} epochs without improvement.')
            break
        

# Plotting the train and val loss
plt.subplot(1, 2, 1)
plt.plot(all_train_loss, label='Train Loss')
plt.plot(all_val_loss, label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train and Val Loss vs. Epochs')
plt.legend()

# Plotting the train and val accuracy in one graph
plt.subplot(1, 2, 2)
plt.plot(all_train_accuracy, label='Train Accuracy')
plt.plot(all_val_accuracy, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Train and Val Accuracy vs. Epochs')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Fold 1/10
# Fold 1/10, Epoch: 1, Train Loss: 3.87992787361145, Train Accuracy: 0.06028905712319339, Val Accuracy: 0.04579207920792079, Val Loss: 3.525160329176648
# Fold 1/10, Epoch: 2, Train Loss: 3.348357915878296, Train Accuracy: 0.13916035788024778, Val Accuracy: 0.05816831683168317, Val Loss: 3.531611919403076
# Fold 3/10, Epoch: 1, Train Loss: 1.9204981327056885, Train Accuracy: 0.4576737783895389, Val Accuracy: 0.31435643564356436, Val Loss: 2.4381308673632027
# Fold 3/10, Epoch: 2, Train Loss: 1.8711522817611694, Train Accuracy: 0.4755677907777013, Val Accuracy: 0.34777227722772275, Val Loss: 2.2828930002627987
# Fold 3/10, Epoch: 3, Train Loss: 1.855167269706726, Train Accuracy: 0.4768066070199587, Val Accuracy: 0.3811881188118812, Val Loss: 2.229389549481987

# %%
torch.save(mdl.state_dict(), "best_cHpnt10fld777.pth")

# %%
print(mdl.state_dict())
# Out:
# OrderedDict({'conv1.weight': tensor([[[[-1.8604e-01, -1.1625e-01, -2.2056e-01],
#           [-2.3414e-02, -3.7739e-02, -8.8040e-02],
#           [ 7.0402e-02,  1.3330e-02,  1.4362e-01]],
#
#          [[ 8.5108e-02,  1.0071e-01, -6.4830e-02],
#           [-2.6175e-02,  1.3800e-02,  5.7989e-02],
#           [-1.0060e-01, -1.1015e-01,  1.6762e-02]],
#
#          [[-3.4322e-02,  1.0945e-01,  1.7141e-01],
#           [-2.1749e-02, -1.4437e-01,  1.2266e-01],
#           [ 2.7816e-02, -1.3480e-01, -1.8985e-01]]],
#
#
#         [[[-9.0463e-02,  1.7367e-01,  7.7679e-02],
#           [ 5.6918e-02, -1.1975e-01, -1.3805e-01],
#           [ 7.9391e-02, -1.3648e-01, -9.5920e-02]],
#
#          [[ 1.4275e-02,  1.3904e-01,  5.8754e-04],
#           [-1.6025e-01,  1.5477e-01, -9.6712e-02],
#           [ 1.3697e-01,  1.3396e-01, -1.4612e-01]],
#
#          [[-9.5365e-02, -2.8231e-02, -8.4894e-02],
#           [ 2.4275e-02, -1.0582e-01, -1.0923e-01],
#           [ 8.9626e-03,  1.0349e-01,  1.4138e-01]]],
#
#
#         [[[-1.0372e-01,  1.1739e-01,  1.0343e-01],
#           [ 2.9068e-02,  9.0368e-02, -7.8015e-02],
#           [ 1.7486e-01,  1.2707e-01, -1.4456e-01]],
#
#          [[-1.6604e-01, -1.8738e-01, -7.9240e-02],
#           [-1.4025e-02,  7.4579e-02,  1.3247e-01],
#           [ 4.3901e-03, -1.5948e-01,  1.7123e-01]],
#
#          [[ 1.2744e-01,  1.3669e-01,  1.2031e-01],
#           [-3.2138e-02, -1.5194e-01, -1.4487e-01],
#           [-4.9300e-03, -6.1681e-02, -7.3036e-02]]],
#
#
#         [[[ 3.9095e-02,  8.6712e-02, -1.3270e-01],
#           [ 8.9384e-03,  7.4709e-02,  7.7095e-03],
#           [-1.3881e-01, -1.0362e-01, -2.4769e-02]],
#
#          [[ 4.5439e-03, -1.5435e-01,  7.0350e-02],
#           [-5.9850e-02,  1.4169e-01, -1.3313e-01],
#           [-9.3886e-02, -7.7724e-02, -5.3081e-02]],
#
#          [[-1.0641e-01, -1.2722e-01, -1.5373e-01],
#           [-1.2938e-01, -1.2714e-02, -7.2299e-02],
#           [-1.3413e-01, -5.8708e-02,  2.1573e-03]]],
#
#
#         [[[-1.0150e-01,  1.3921e-01, -1.3785e-01],
#           [ 2.5513e-02, -6.2303e-02,  2.4113e-04]],
#
#          [[-1.3638e-01, -6.9707e-03,  3.4311e-02],
#           [ 1.7263e-01,  4.3253e-02,  1.2419e-01],
#           [ 8.8139e-02,  1.9739e-01,  1.1938e-01]],
#
#          [[ 9.8914e-02, -1.4786e-01,  6.6441e-02],
#           [-1.2977e-01,  1.0720e-01,  4.0026e-02],
#           [-1.6579e-01, -1.8797e-01, -1.2403e-01]]],
#
#
#         [[[ 4.7778e-02, -4.5971e-02, -1.6639e-01],
#           [-1.5828e-02,  1.4441e-01, -4.7378e-02],
#           [-7.2620e-02,  9.8013e-02,  1.1394e-01]],
#
#          [[ 4.6752e-02,  8.6532e-03,  1.0895e-02],
#           [-1.0668e-01,  7.0332e-02, -1.6132e-01],
#           [ 1.0631e-01, -4.1503e-02,  1.6744e-01]],
#
#          [[-3.7875e-02,  5.0557e-02, -2.1958e-04],
#           [ 1.3509e-01, -1.1796e-01,  3.4985e-02],
#           [ 1.0654e-01, -1.4254e-02,  1.3732e-02]]],
#
#
#         [[[ 9.3186e-03, -6.6806e-03, -1.5335e-01],
#           [ 9.9491e-03, -1.3718e-01, -1.0270e-01],
#           [-2.0953e-01, -6.8225e-02, -1.2520e-02]],
#
#          [[ 1.2303e-01,  1.1620e-01,  4.8015e-02],
#           [-1.8201e-01, -1.7852e-01,  9.7247e-02],
#           [ 1.5334e-01, -9.6327e-02,  5.5096e-03]],
#
#          [[ 1.0768e-01,  1.2668e-01, -1.3053e-01],
#           [-1.3375e-01,  1.2141e-01, -1.8604e-01],
#           [-2.0632e-01,  1.6675e-01, -4.9138e-02]]]], device='cuda:0'), 'conv1.bias': tensor([ 1.0981e-04, -1.2748e-04, -3.6752e-04, -1.5810e-05,  1.5327e-04,
#          6.7098e-06,  2.1083e-04, -4.1602e-05,  3.0755e-04, -1.0838e-04,
#          1.0410e-05,  3.5399e-06], device='cuda:0'), 'btch1.weight': tensor([0.9945, 0.9580, 1.0243, 1.0104, 0.9487, 1.0510, 0.9676, 0.9982, 0.9837,
#         1.0330, 0.9763, 0.9727], device='cuda:0'), 'btch1.bias': tensor([-0.0063,  0.0070,  0.0900,  0.0599, -0.0472, -0.1173, -0.0102,  0.0557,
#          0.0013, -0.0963,  0.0376, -0.0251], device='cuda:0'), 'btch1.running_mean': tensor([ 0.0613,  0.0398,  0.0241,  0.2770,  0.0306,  0.1785, -0.0415, -0.1938,
#          0.0429,  0.0839, -0.0629,  0.0916], device='cuda:0'), 'btch1.running_var': tensor([0.0661, 0.0107, 0.0063, 0.3369, 0.0150, 0.0473, 0.0273, 0.2002, 0.0124,
#         0.0231, 0.0234, 0.1247], device='cuda:0'), 'btch1.num_batches_tracked': tensor(11172, device='cuda:0'), 'conv2.weight': tensor([[[[-5.5851e-02,  1.3435e-02,  1.0079e-01],
#           [-5.0927e-02, -7.0014e-02,  9.8282e-03],
#           [ 6.5212e-02,  3.2213e-03,  1.5826e-02]],
#
#          [[-5.2997e-02, -4.3082e-02,  4.7988e-03],
#         0.8085, 0.8065, 0.8438, 0.7871, 0.7881, 0.8218, 0.8048, 0.8365, 0.7949,
#         0.8118, 0.8084, 0.8062, 0.7953, 0.8339], device='cuda:0'), 'btch3.bias': tensor([-0.1748, -0.2063, -0.1916, -0.2231, -0.2054, -0.1941, -0.2121, -0.2387,
#         -0.2187, -0.1836, -0.1539, -0.2334, -0.2431, -0.1745, -0.2038, -0.2349,
#         -0.1831, -0.1840, -0.2036, -0.1989, -0.2049, -0.1997, -0.2263, -0.1876,
#         -0.2136, -0.1697, -0.2286, -0.2168, -0.2055, -0.1921, -0.2244, -0.1909],
#        device='cuda:0'), 'btch3.running_mean': tensor([-0.0737, -0.1458, -0.0280, -0.0462, -0.0602, -0.1384, -0.0256, -0.0243,
#         -0.1130, -0.0965, -0.1150, -0.1621, -0.0747, -0.0333, -0.0509, -0.1276,
#         -0.0939, -0.1470, -0.0944, -0.0918,  0.0200, -0.0685, -0.1830, -0.0885,
#         -0.1691, -0.0491, -0.0780, -0.0701, -0.0956, -0.1096,  0.0291, -0.0212],
#        device='cuda:0'), 'btch3.running_var': tensor([0.1536, 0.1570, 0.0910, 0.0534, 0.0384, 0.0453, 0.0439, 0.0223, 0.1378,
#         0.0781, 0.0303, 0.1762, 0.0544, 0.0748, 0.0579, 0.0380, 0.0431, 0.1481,
#         0.0831, 0.0484, 0.1393, 0.0494, 0.0573, 0.1046, 0.1044, 0.0305, 0.0404,
#         0.0781, 0.0824, 0.1449, 0.0245, 0.0584], device='cuda:0'), 'btch3.num_batches_tracked': tensor(11172, device='cuda:0'), 'fc.weight': tensor([[ 0.0058,  0.0009,  0.0053,  ...,  0.0100, -0.0108, -0.0027],
#         [ 0.0006, -0.0029, -0.0105,  ..., -0.0070,  0.0030, -0.0081],
#         [-0.0031, -0.0178, -0.0133,  ..., -0.0161, -0.0069, -0.0196],
#         ...,
#         [-0.0036,  0.0022, -0.0005,  ..., -0.0072, -0.0196, -0.0079],
#         [-0.0076, -0.0004,  0.0054,  ..., -0.0040, -0.0090,  0.0003],
#         [ 0.0132, -0.0044, -0.0042,  ..., -0.0080,  0.0032, -0.0082]],
#        device='cuda:0'), 'fc.bias': tensor([ 2.7999e-03,  6.3671e-03, -8.2488e-03,  4.0238e-04,  7.0473e-04,
#          9.6439e-03, -7.7080e-04,  3.9328e-03, -3.2125e-03, -8.2212e-03,
#          2.2804e-03, -3.4275e-04, -1.2858e-03, -2.3206e-04,  1.7951e-03,
#          7.4730e-04,  1.1776e-02,  2.9001e-03, -7.8573e-04,  3.0557e-03,
#         -7.4290e-04, -3.3012e-03,  3.8274e-03, -1.9973e-03, -7.3713e-04,
#         -1.1741e-03, -1.6529e-03, -4.7959e-05, -2.2132e-03,  3.3926e-03,
#         -6.2133e-03, -1.6627e-03, -8.5316e-04,  1.3519e-03, -3.6278e-03,
#         -2.7255e-03, -2.9744e-03, -8.1902e-04], device='cuda:0')})

# %% [markdown]
# Testing

# %%
import torch
import torch.nn as nn
from torchvision.transforms import transforms
import numpy as np
from torch.autograd import Variable
from torchvision.models import squeezenet1_1
import torch.functional as F
from io import open
import os
from PIL import Image
import pathlib
import glob
import cv2

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device , "is available")
# Out:
# cuda is available

# %%
#Transform test data
trnsfrm=transforms.Compose([
    transforms.Resize((150,150)),
    transforms.ToTensor(),  #0-255 to 0-1, numpy to tensors
    transforms.Normalize([0.5,0.5,0.5],
                        [0.5,0.5,0.5])
    ])

# %%
checkpoint=torch.load("best_cHpnt10fld500.pth")
mdl=ConvNet(num_classes=38).to(device) # num_classes 38 huna parxa
mdl.load_state_dict(checkpoint)
# torch.load(model.state_dict(), os.path.join(
#                         model_dir, "/Users/risal/My_Codes/Projectdataminor/traintestsplit/checkpoint10.pth"))
mdl.eval()
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (btch1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(12, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU()
#   (dropout1): Dropout(p=0.3, inplace=False)
#   (conv3): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (btch3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=180000, out_features=38, bias=True)
# )

# %%
print(mdl.state_dict())
# Out:
# OrderedDict({'conv1.weight': tensor([[[[ 0.1468, -0.0258, -0.1411],
#           [-0.1107, -0.1083,  0.1798],
#           [ 0.0034,  0.0546,  0.0722]],
#
#          [[ 0.0795, -0.0262,  0.0602],
#           [-0.0949,  0.1697, -0.0841],
#           [-0.0139,  0.0022, -0.0225]],
#
#          [[ 0.1661, -0.0379, -0.1568],
#           [-0.1590,  0.0490,  0.0383],
#           [ 0.0983,  0.1202,  0.0937]]],
#
#
#         [[[-0.1445, -0.0046,  0.0272],
#           [ 0.0413,  0.1167,  0.0642],
#           [-0.0186, -0.1735, -0.0467]],
#
#          [[-0.0131, -0.0071,  0.0220],
#           [ 0.0757, -0.1898, -0.0011],
#           [ 0.1325, -0.0960,  0.0339]],
#
#          [[ 0.1644,  0.1260,  0.1693],
#           [ 0.2033, -0.0013,  0.1712],
#           [ 0.0465,  0.1863,  0.0638]]],
#
#
#         [[[ 0.1278, -0.1391,  0.1843],
#           [ 0.1261, -0.0072, -0.0792],
#           [ 0.0948,  0.0371, -0.1604]],
#
#          [[-0.1625, -0.0100,  0.1193],
#           [ 0.1839, -0.0830,  0.1461],
#           [-0.1213, -0.0375,  0.0834]],
#
#          [[-0.0660,  0.2096, -0.0169],
#           [ 0.0994, -0.1576, -0.0555],
#           [-0.0033,  0.1953, -0.0449]]],
#
#
#         [[[ 0.0417, -0.0673,  0.1582],
#           [-0.0431, -0.0548, -0.0119],
#           [-0.1210,  0.0268,  0.0412]],
#
#          [[-0.1032, -0.0053,  0.1182],
#           [-0.0813,  0.1382, -0.0133],
#           [-0.1292,  0.0169,  0.0720]],
#
#          [[ 0.0343,  0.1041,  0.0438],
#           [-0.0688, -0.1512,  0.1031],
#           [-0.2059, -0.0293,  0.1840]]],
#
#
#         [[[-0.1169, -0.0812, -0.0797],
#           [-0.0411,  0.1794, -0.1409],
#           [ 0.1093, -0.1122, -0.0120]],
#
#          [[ 0.0988, -0.1355, -0.0276],
#           [ 0.0296,  0.0143,  0.0009],
#           [ 0.0157, -0.0785,  0.0943]],
#
#          [[ 0.1993, -0.1215,  0.0671],
#           [-0.1028,  0.1075,  0.0004],
#           [-0.1115, -0.0473,  0.1685]]],
#
#
#         [[[ 0.0555,  0.0178, -0.1080],
#           [ 0.1684,  0.1702,  0.0025],
#           [ 0.1428,  0.0330,  0.1651]],
#
#          [[ 0.1403,  0.0997,  0.0962],
#           [-0.1051, -0.1874,  0.0337],
#           [-0.1261, -0.0793,  0.0823]],
#
#          [[ 0.0330, -0.0107,  0.2132],
#           [ 0.0927, -0.1447, -0.0125],
#           [ 0.0788, -0.0052,  0.1268]]],
#
#
#         [[[-0.0343,  0.1430,  0.0850],
#           [-0.0178, -0.1521,  0.0123],
#           [ 0.1588,  0.0345, -0.1068]],
#
#          [[-0.0881,  0.0198,  0.1477],
#           [-0.1689, -0.1526, -0.1606],
#           [ 0.1580, -0.1882, -0.0662]],
#
#          [[-0.0361,  0.1538,  0.1405],
#           [-0.0038,  0.0391,  0.0188],
#           [ 0.0449,  0.0821, -0.2203]]],
#
#
#         [[[-0.1354, -0.1203, -0.1528],
#           [ 0.1142,  0.1912, -0.0664],
#           [ 0.1040,  0.1561, -0.0621]],
#
#          [[-0.0466, -0.1747,  0.0711],
#           [ 0.1706, -0.1269,  0.1311],
#           [-0.0317, -0.1587,  0.1330]],
#
#          [[-0.0605,  0.0474, -0.0726],
#           [-0.0844, -0.0848,  0.2049],
#           [ 0.1054,  0.0566, -0.1407]]],
#
#
#         [[[ 0.1721, -0.1102, -0.2135],
#           [ 0.1561, -0.1041,  0.0114],
#           [ 0.1830,  0.0544, -0.1738]],
#
#          [[-0.0452,  0.0073, -0.0947],
#           [-0.0403,  0.1080, -0.1899],
#           [ 0.1149,  0.1443, -0.1920]],
#
#          [[ 0.1344, -0.1955,  0.0947],
#           [ 0.0400, -0.1366,  0.1608],
#           [ 0.1669, -0.1791,  0.1383]]],
#
#
#         [[[ 0.0093,  0.1321,  0.1712],
#           [ 0.1763,  0.1321,  0.0043],
#           [ 0.0437,  0.1333, -0.1692]],
#
#          [[-0.0748, -0.1049, -0.0695],
#           [ 0.1400, -0.1255, -0.1564],
#           [-0.0493, -0.0439, -0.0386]],
#
#          [[ 0.1046, -0.1633, -0.0048],
#           [ 0.1043,  0.0890, -0.0023],
#           [-0.1600,  0.1526, -0.2016]]],
#
#
#         [[[ 0.0133, -0.1283, -0.1717],
#           [ 0.1596,  0.0989,  0.0890],
#           [-0.1458, -0.1223, -0.1027]],
#
#          [[-0.0839, -0.1525, -0.0704],
#           [-0.0924, -0.2346, -0.0986],
#           [-0.0854, -0.1049, -0.1742]],
#
#          [[ 0.1029, -0.1553,  0.1297],
#           [-0.0037,  0.1030, -0.0531],
#           [-0.1766, -0.0586, -0.1185]]],
#
#
#         [[[-0.0103, -0.1557,  0.0750],
#           [ 0.0243,  0.0553,  0.1351],
#           [-0.0323, -0.0582,  0.0662]],
#
#          [[-0.1013, -0.0289,  0.0981],
#           [ 0.1158,  0.1850, -0.1816],
#           [-0.0985,  0.1308,  0.0002]],
#
#          [[ 0.0511,  0.0986, -0.1063],
#           [ 0.0247, -0.1841,  0.0379],
#           [-0.1068, -0.0188,  0.0141]]]], device='cuda:0'), 'conv1.bias': tensor([-9.4423e-05, -3.4700e-05, -8.0996e-05,  2.5243e-04,  2.3689e-04,
#         -8.5107e-05,  1.1547e-04, -3.9542e-04,  2.1957e-04, -6.0176e-06,
#         -3.1665e-05, -4.4420e-04], device='cuda:0'), 'btch1.weight': tensor([0.9836, 0.9952, 0.9686, 0.9561, 0.9775, 0.9755, 0.9625, 1.0768, 0.9570,
#         0.9898, 0.9677, 0.9962], device='cuda:0'), 'btch1.bias': tensor([-0.0629, -0.0129,  0.0046, -0.0735, -0.0910, -0.0283,  0.0401, -0.0571,
#         -0.0741,  0.0708, -0.0059,  0.0385], device='cuda:0'), 'btch1.running_mean': tensor([-0.0794, -0.3186, -0.0819, -0.0010, -0.0175, -0.1733, -0.0179,  0.0069,
#         -0.0411,  0.0194,  0.2323,  0.0312], device='cuda:0'), 'btch1.running_var': tensor([0.0261, 0.2249, 0.0406, 0.0156, 0.0089, 0.1768, 0.0214, 0.0065, 0.0199,
#         0.0241, 0.5117, 0.0044], device='cuda:0'), 'btch1.num_batches_tracked': tensor(9991, device='cuda:0'), 'conv2.weight': tensor([[[[-0.0562,  0.0514, -0.0140],
#           [ 0.0652, -0.0011, -0.1003],
#           [-0.0997,  0.0555, -0.0495]],
#
#          [[ 0.0404, -0.0954, -0.0831],
#           [ 0.0321, -0.0203, -0.1005],
#           [ 0.0437, -0.0458,  0.0455]],
#
#          [[ 0.0574,  0.0492, -0.0313],
#           [-0.0194,  0.0221, -0.0740],
#           [ 0.0236,  0.0843,  0.0264]],
#
#          ...,
#
#          [[-0.0805,  0.0262, -0.0577],
#           [-0.0505,  0.0365,  0.0077],
#           [ 0.0616, -0.0795,  0.0706]],
#
#          [[ 0.0256, -0.0337,  0.0789],
#           [-0.0420,  0.0729,  0.0309],
#           [ 0.0609,  0.0577, -0.0540]],
#
#          [[ 0.0209, -0.0575, -0.1040],
#           [ 0.0870, -0.0611, -0.0626],
#           [-0.0321,  0.0937,  0.0986]]],
#
#
#         [[[-0.0662,  0.0635, -0.0115],
#           [ 0.0546,  0.0779,  0.0680],
#           [ 0.0513,  0.0713,  0.0164]],
#
#          [[ 0.0467,  0.0222, -0.0136],
#           [-0.0786, -0.0510, -0.0282],
#           [ 0.0450, -0.0140,  0.0434]],
#
#          [[-0.1141, -0.0697,  0.0478],
#           [-0.0131, -0.0706,  0.0652],
#           [-0.0041, -0.0029,  0.0666]],
#
#          ...,
#
#          [[-0.0758, -0.0036,  0.0339],
#           [-0.0146, -0.0255, -0.0633],
#           [-0.0264,  0.0425, -0.0650]],
#
#          [[ 0.0291, -0.0868, -0.0178],
#           [ 0.0133, -0.0534, -0.0408],
#           [-0.0349,  0.0557,  0.0128]],
#
#          [[ 0.0032, -0.0777, -0.0979],
#           [ 0.0473, -0.0045,  0.0004],
#           [-0.0570,  0.0600, -0.0494]]],
#
#
#         [[[ 0.0573, -0.0047,  0.0135],
#           [ 0.0251,  0.0793,  0.0146],
#           [-0.0544, -0.0038,  0.0757]],
#
#          [[-0.0461,  0.0434,  0.0461],
#           [-0.0098, -0.0698,  0.0782],
#           [ 0.0354, -0.0806, -0.0722]],
#
#          [[-0.0429, -0.0724, -0.0530],
#           [-0.0425, -0.0959,  0.0841],
#           [-0.0106,  0.0258, -0.0138]],
#
#          ...,
#
#          [[-0.1169, -0.0325, -0.0217],
#           [ 0.0126,  0.0434, -0.1207],
#           [ 0.0405,  0.0972, -0.0026]],
#
#          [[-0.0924, -0.0044, -0.0427],
#           [ 0.0649,  0.0144, -0.0389],
#           [-0.0370,  0.0462,  0.0220]],
#
#          [[-0.0551, -0.0239, -0.0872],
#           [-0.0307,  0.0109, -0.0069],
#           [ 0.0352, -0.0327,  0.0839]]],
#
#
#         ...,
#
#
#         [[[-0.0606,  0.0783, -0.0467],
#           [ 0.0788,  0.0754, -0.0785],
#           [ 0.0592,  0.0558, -0.0678]],
#
#          [[-0.0512,  0.0240,  0.0440],
#           [-0.0449,  0.0329,  0.0057],
#           [ 0.0833, -0.0503, -0.0590]],
#
#          [[-0.0111,  0.0283, -0.0527],
#           [ 0.0533, -0.0114,  0.0034],
#           [-0.0947, -0.0318,  0.0491]],
#
#          ...,
#
#          [[ 0.0040, -0.0140, -0.0942],
#           [-0.0137,  0.0257,  0.0610],
#           [ 0.0734, -0.0027,  0.0130]],
#
#          [[ 0.0314, -0.0439,  0.0762],
#           [-0.0580,  0.0793,  0.0173],
#           [-0.0466,  0.0484, -0.0608]],
#
#          [[ 0.0751, -0.0543, -0.0179],
#           [ 0.0098, -0.0525,  0.0202],
#           [ 0.0374, -0.0597,  0.0129]]],
#
#
#         [[[ 0.0112,  0.0668,  0.0224],
#           [-0.0151,  0.0243,  0.0724],
#           [-0.0309,  0.0280,  0.0180]],
#
#          [[-0.0281, -0.0528, -0.0787],
#           [ 0.0112, -0.0558,  0.0264],
#           [ 0.0801,  0.0159,  0.0129]],
#
#          [[-0.0190,  0.0192,  0.0643],
#           [-0.0324,  0.0359,  0.0181],
#           [ 0.0145,  0.0841,  0.0331]],
#
#          ...,
#
#          [[-0.0042,  0.0478, -0.0260],
#           [-0.0121, -0.0649, -0.0435],
#           [-0.0173, -0.0618,  0.0092]],
#
#          [[ 0.0399, -0.0745,  0.0402],
#           [-0.0099, -0.0610,  0.0530],
#           [-0.0221,  0.0533,  0.0435]],
#
#          [[-0.0195, -0.0040,  0.0219],
#           [-0.0319,  0.0002, -0.0911],
#           [-0.1165, -0.0033, -0.0422]]],
#
#
#         [[[ 0.0989, -0.0078,  0.0434],
#           [ 0.0005,  0.0587,  0.0694],
#           [-0.0009,  0.0562, -0.0323]],
#
#          [[-0.0763, -0.0652, -0.0342],
#           [ 0.0598, -0.0336,  0.0036],
#           [ 0.0218, -0.0824,  0.0298]],
#
#          [[ 0.0530, -0.0293,  0.0646],
#           [ 0.1104, -0.0621, -0.0604],
#           [ 0.1023, -0.0327, -0.0785]],
#
#          ...,
#
#          [[-0.0501,  0.0717,  0.0175],
#           [ 0.0186,  0.0297, -0.0313],
#           [ 0.0758, -0.0092, -0.0828]],
#
#          [[-0.0081,  0.0853, -0.0655],
#           [-0.0828,  0.0218, -0.0581],
#           [-0.0859,  0.0805, -0.0316]],
#
#          [[-0.0297,  0.0835, -0.0838],
#           [ 0.0799,  0.0277, -0.0364],
#           [ 0.0017,  0.0451, -0.0054]]]], device='cuda:0'), 'conv2.bias': tensor([-0.1501, -0.1186, -0.1002,  0.0689, -0.0931,  0.0705,  0.0807,  0.0090,
#         -0.0184, -0.0476, -0.1416, -0.0720, -0.0797,  0.0305, -0.1044, -0.1788,
#         -0.0174,  0.0121, -0.1112, -0.0775], device='cuda:0'), 'conv3.weight': tensor([[[[ 3.4752e-02,  3.2660e-02, -4.3269e-02],
#           [ 3.3563e-02,  3.7117e-02, -3.7750e-03],
#           [ 2.2844e-02, -5.4543e-03,  5.2171e-02]],
#
#          [[ 2.7996e-02,  6.7436e-02, -2.6587e-02],
#           [ 6.7584e-02,  1.9836e-02,  3.3596e-02],
#           [ 8.6753e-02, -2.1933e-02, -3.0280e-02]],
#
#          [[-7.1962e-02, -9.8525e-02, -5.3779e-02],
#           [-3.1783e-02, -4.3889e-02, -7.7661e-02],
#           [ 1.0597e-02, -5.5697e-02, -4.2375e-02]],
#
#          ...,
#
#          [[ 1.1042e-02, -1.1364e-02, -6.1931e-02],
#           [-6.1169e-02, -5.8593e-02, -2.7641e-02],
#           [ 2.5121e-02,  3.8002e-02, -2.5269e-02]],
#
#          [[-7.6289e-02,  2.7262e-03, -4.3188e-02],
#           [-5.4240e-02,  4.4411e-03,  4.9813e-02],
#           [-2.5825e-02, -1.8795e-02,  2.4789e-02]],
#
#          [[-3.2196e-02,  2.6173e-02, -3.3688e-03],
#           [-4.2404e-02,  2.9923e-02,  1.4436e-02],
#           [ 4.2184e-02,  2.3120e-02,  3.4044e-02]]],
#
#
#         [[[-3.7891e-02,  5.3965e-02, -5.5856e-02],
#           [ 2.6763e-02, -2.5069e-05, -3.4546e-02],
#           [-5.6328e-02, -1.1688e-02, -3.9033e-03]],
#
#          [[ 5.0423e-02, -5.1745e-02, -1.7748e-02],
#           [-2.4399e-02, -3.9545e-02, -4.4459e-02],
#           [ 4.9755e-02, -3.1764e-02,  1.5932e-02]],
#
#          [[-5.2236e-02, -3.4361e-02, -5.9120e-03],
#           [-7.5670e-02,  1.5958e-02, -8.5727e-02],
#           [-5.2369e-02, -6.5783e-02, -2.0396e-02]],
#
#          ...,
#
#          [[ 1.4765e-02,  6.5188e-02, -4.2672e-02],
#           [ 1.3484e-02, -1.0995e-02, -5.7778e-02],
#           [-5.3810e-02,  2.7698e-02, -2.6961e-02]],
#
#           [-1.9405e-02, -7.6105e-02, -4.4403e-04],
#           [ 6.9752e-02,  6.6210e-02,  1.9548e-02]],
#
#          [[-1.1647e-02,  4.7431e-02, -5.4964e-04],
#           [-6.4194e-02, -3.2666e-03, -3.8201e-02],
#           [-2.3882e-02, -4.0139e-02,  1.4397e-02]],
#
#          ...,
#
#          [[ 1.6692e-02,  2.1352e-02,  3.2710e-02],
#           [ 4.4814e-02, -2.3157e-02,  9.7994e-03],
#           [-3.4779e-02, -2.6707e-02,  4.3003e-02]],
#
#          [[ 1.0260e-02, -1.0119e-02,  8.9202e-03],
#           [ 2.1380e-02, -3.8499e-02,  2.0359e-02],
#           [ 5.8821e-02,  4.2098e-02,  5.8263e-02]],
#
#          [[-2.4173e-02, -5.6391e-03,  5.1686e-02],
#           [ 2.0645e-02,  1.5274e-02,  2.4442e-03],
#           [ 2.0501e-03,  1.0740e-02, -3.5447e-02]]],
#
#
#         [[[ 3.8808e-02,  1.1845e-01,  4.4070e-02],
#           [ 5.7614e-02,  1.0966e-01,  2.6294e-02],
#           [ 7.5872e-02, -1.2691e-02,  1.1138e-01]],
#
#          [[-4.0638e-02, -3.7344e-02,  4.7415e-02],
#           [ 5.1337e-02,  6.3296e-02,  2.4614e-02],
#           [-4.5500e-02, -1.3175e-02, -4.8525e-02]],
#
#          [[ 1.9848e-02, -1.2023e-01, -5.3265e-02],
#           [-1.0873e-01, -9.9253e-02, -7.8868e-02],
#           [-2.0759e-02,  8.2720e-04,  5.2808e-02]],
#
#          ...,
#
#          [[ 5.8556e-02, -1.2747e-02, -4.3782e-02],
#           [ 1.4613e-02, -3.2555e-02, -6.0166e-03],
#           [-3.4836e-02,  4.5806e-02,  4.7133e-02]],
#
#          [[-2.0296e-02, -1.6792e-02,  2.2721e-02],
#           [-5.4998e-02, -8.8869e-02, -5.9161e-02],
#           [-7.3400e-02, -3.5330e-02,  4.3400e-02]],
#
#          [[-1.1627e-02,  2.0981e-02,  2.4981e-02],
#           [ 1.7112e-02, -5.4048e-02, -3.1005e-02],
#           [-1.2187e-02, -2.2932e-02, -2.5561e-02]]]], device='cuda:0'), 'conv3.bias': tensor([-7.3190e-06, -9.7065e-05, -3.8581e-05, -5.5330e-05, -1.7800e-05,
#         -8.2691e-05,  7.4896e-06,  1.1898e-04, -2.3492e-05, -1.3014e-04,
#         -1.2029e-05,  1.6204e-05, -2.7486e-06,  3.9204e-05,  7.4665e-05,
#         -1.0187e-04, -1.6639e-05,  1.3083e-05,  3.9042e-05, -1.8529e-04,
#         -5.7722e-05, -1.5094e-04, -3.2573e-05,  2.9580e-05, -1.1284e-04,
#         -1.3268e-04, -2.0952e-05,  7.6137e-06, -1.2384e-05,  5.1886e-05,
#          1.6336e-04,  1.9290e-05], device='cuda:0'), 'btch3.weight': tensor([0.8048, 0.8342, 0.7429, 0.7826, 0.7777, 0.7681, 0.7698, 0.8053, 0.7360,
#         0.7944, 0.7923, 0.8007, 0.7748, 0.8108, 0.8009, 0.7891, 0.7790, 0.7942,
#         0.7967, 0.8431, 0.8038, 0.7763, 0.7877, 0.8262, 0.7838, 0.8354, 0.7480,
#         0.7425, 0.8081, 0.7454, 0.7960, 0.7861], device='cuda:0'), 'btch3.bias': tensor([-0.2172, -0.2060, -0.2370, -0.2336, -0.2160, -0.2347, -0.2498, -0.1832,
#         -0.2618, -0.2175, -0.2079, -0.2061, -0.2204, -0.1879, -0.2105, -0.2130,
#         -0.2512, -0.2137, -0.2140, -0.1953, -0.1933, -0.1958, -0.2454, -0.1740,
#         -0.2006, -0.1911, -0.2434, -0.2489, -0.1925, -0.2559, -0.1952, -0.2143],
#        device='cuda:0'), 'btch3.running_mean': tensor([-0.1093, -0.3512, -0.0670, -0.1376, -0.0767, -0.0492, -0.0692, -0.1044,
#         -0.1132, -0.2427, -0.0318, -0.0610, -0.1380, -0.1810, -0.1236, -0.1048,
#          0.0113, -0.0295, -0.2136, -0.2137, -0.0511, -0.1091, -0.0671, -0.1848,
#         -0.0956, -0.1021, -0.1668, -0.1261, -0.1208, -0.1440, -0.0125, -0.1236],
#        device='cuda:0'), 'btch3.running_var': tensor([0.1100, 0.2401, 0.0506, 0.0749, 0.0567, 0.0550, 0.0834, 0.0590, 0.0707,
#         0.1333, 0.0730, 0.0303, 0.0708, 0.0425, 0.0685, 0.0870, 0.0491, 0.0402,
#         0.1087, 0.2051, 0.0587, 0.0525, 0.0510, 0.0719, 0.0717, 0.0932, 0.0838,
#         0.0849, 0.1355, 0.0468, 0.0358, 0.1077], device='cuda:0'), 'btch3.num_batches_tracked': tensor(9991, device='cuda:0'), 'fc.weight': tensor([[-0.0004,  0.0025, -0.0010,  ...,  0.0047, -0.0006, -0.0159],
#         [-0.0089,  0.0059,  0.0022,  ...,  0.0006, -0.0041, -0.0017],
#         [-0.0015, -0.0035, -0.0050,  ...,  0.0023, -0.0037,  0.0032],
#         ...,
#         [-0.0033, -0.0129, -0.0118,  ...,  0.0082,  0.0015,  0.0040],
#         [ 0.0017, -0.0101,  0.0018,  ..., -0.0041, -0.0071, -0.0010],
#         [-0.0068, -0.0009,  0.0097,  ...,  0.0061, -0.0048, -0.0015]],
#        device='cuda:0'), 'fc.bias': tensor([ 0.0035, -0.0003, -0.0046,  0.0039,  0.0004,  0.0056, -0.0015,  0.0018,
#         -0.0017, -0.0024,  0.0010, -0.0056, -0.0041,  0.0004, -0.0015,  0.0022,
#          0.0040,  0.0028, -0.0030, -0.0033, -0.0017,  0.0014, -0.0018,  0.0007,
#         -0.0008,  0.0010,  0.0011, -0.0036, -0.0005,  0.0044, -0.0040,  0.0004,
#         -0.0009, -0.0020,  0.0018, -0.0020, -0.0002,  0.0040], device='cuda:0')})

# %%
mdl.to(device)
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (btch1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(12, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU()
#   (dropout1): Dropout(p=0.3, inplace=False)
#   (conv3): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (btch3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=180000, out_features=38, bias=True)
# )

# %%
def prediction(img_path, trnsfrm, mdl, class_labels, device):
    try:
        image = Image.open(img_path).convert('RGB')
        image_tensor = trnsfrm(image).float()
        image_tensor = image_tensor.unsqueeze_(0)

        image_tensor = image_tensor.to(device)  # Move tensor to device

        output = mdl(image_tensor)
        _, index = output.data.cpu().max(1)  # Get the index of the max log-probability
        label_index = index.item()

        # Convert label index to the corresponding label
        pred_label = list(class_labels.values())[list(class_labels.values()).index(label_index)]

        return pred_label
    except Exception as e:
        print(f"Error during prediction for image {img_path}: {str(e)}")
        return None

# %%
# C:\Users\risal\My_Codes\Projectdataminor\traintestsplit\Dataset\pred
images_path=glob.glob('/Users/risal/My_Codes/Projectdataminor/traintestsplit/Dataset/pred/*')
# test_loader = DataLoader(images_path, shuffle=True, batch_size=32)

# %%
pred_dict={}

for i in images_path:
    pred_dict[i[i.rfind('/') + 1:]] = prediction(i, trnsfrm, mdl, class_labels, device)

# %%
pred_dict
# Out:
# {'pred\\Abbott’s Babbler Malacocincla abbotti 106.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 136.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 140.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 21.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 36.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 51.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 8.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 95.jpg': 0,
#  'pred\\Black Bittern (Dupetor flavicollis) 11.png': 35,
#  'pred\\Black Bittern (Dupetor flavicollis) 12.png': 10,
#  'pred\\Black Bittern (Dupetor flavicollis) 14.png': 1,
#  'pred\\Black Bittern (Dupetor flavicollis) 152.png': 1,
#  'pred\\Black Bittern (Dupetor flavicollis) 159.png': 1,
#  'pred\\Black Bittern (Dupetor flavicollis) 184.png': 19,
#  'pred\\Black Bittern (Dupetor flavicollis) 199.png': 5,
#  'pred\\Black Bittern (Dupetor flavicollis) 217.png': 29,
#  'pred\\Black Bittern (Dupetor flavicollis) 226.png': 31,
#  'pred\\Black Bittern (Dupetor flavicollis) 246.png': 5,
#  'pred\\Black Bittern (Dupetor flavicollis) 250.png': 25,
#  'pred\\Black Bittern (Dupetor flavicollis) 80.png': 1,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 11.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 113.png': 24,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 123.png': 10,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 137.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 158.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 161.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 184.png': 24,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 28.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 34.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 55.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 68.png': 2,
#  'pred\\Blue-naped Pitta Pitta nipalensis 149.png': 3,
#  'pred\\Blue-naped Pitta Pitta nipalensis 158.png': 33,
#  'pred\\Blue-naped Pitta Pitta nipalensis 161.png': 0,
#  'pred\\Blue-naped Pitta Pitta nipalensis 174.png': 3,
#  'pred\\Blue-naped Pitta Pitta nipalensis 176.png': 3,
#  'pred\\Blue-naped Pitta Pitta nipalensis 177.png': 5,
#  'pred\\Blue-naped Pitta Pitta nipalensis 21.png': 3,
#  'pred\\Blue-naped Pitta Pitta nipalensis 77.png': 3,
#  'pred\\Blue-naped Pitta Pitta nipalensis 79.png': 3,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 136.png': 4,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 17.png': 4,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 2.png': 4,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 36.png': 4,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 57.png': 4,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 83.png': 23,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 84.png': 4,
#  'pred\\Cheer Pheasant (Catreus wallichii) 122.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 132.png': 31,
#  'pred\\Cheer Pheasant (Catreus wallichii) 140.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 153.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 172.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 182.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 28.png': 25,
#  'pred\\Cheer Pheasant (Catreus wallichii) 29.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 37.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 44.png': 31,
#  'pred\\Chestnut Munia Lonchura atricapilla 140.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 145.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 150.png': 5,
#  'pred\\Chestnut Munia Lonchura atricapilla 166.png': 10,
#  'pred\\Chestnut Munia Lonchura atricapilla 179.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 182.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 222.png': 34,
#  'pred\\Chestnut Munia Lonchura atricapilla 27.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 46.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 59.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 6.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 71.png': 6,
#  'pred\\Cinereous Vulture Aegypius monachus 1.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 105.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 114.png': 9,
#  'pred\\Cinereous Vulture Aegypius monachus 136.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 171.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 195.png': 5,
#  'pred\\Cinereous Vulture Aegypius monachus 210.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 215.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 234.png': 23,
#  'pred\\Cinereous Vulture Aegypius monachus 245.png': 22,
#  'pred\\Cinereous Vulture Aegypius monachus 39.png': 31,
#  'pred\\Cinereous Vulture Aegypius monachus 94.png': 7,
#  'pred\\Golden Babbler Stachyris chrysaea 125.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 153.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 164.png': 3,
#  'pred\\Golden Babbler Stachyris chrysaea 191.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 195.png': 0,
#  'pred\\Golden Babbler Stachyris chrysaea 197.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 22.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 86.png': 37,
#  'pred\\Golden Babbler Stachyris chrysaea 93.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 98.png': 8,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 106.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 146.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 162.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 35.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 54.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 60.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 62.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 67.png': 9,
#  'pred\\Great Bittern Botaurus stellaris 102.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 110.png': 0,
#  'pred\\Great Bittern Botaurus stellaris 117.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 157.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 164.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 17.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 172.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 18.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 189.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 203.png': 5,
#  'pred\\Great Bittern Botaurus stellaris 30.png': 1,
#  'pred\\Great Bittern Botaurus stellaris 49.png': 10,
#  'pred\\Great Hornbill (Buceros bicornis) 152.png': 11,
#  'pred\\Great Hornbill (Buceros bicornis) 158.png': 19,
#  'pred\\Great Hornbill (Buceros bicornis) 185.png': 11,
#  'pred\\Great Hornbill (Buceros bicornis) 30.png': 11,
#  'pred\\Great Hornbill (Buceros bicornis) 47.png': 19,
#  'pred\\Great Hornbill (Buceros bicornis) 50.png': 5,
#  'pred\\Great Hornbill (Buceros bicornis) 54.png': 19,
#  'pred\\Great Hornbill (Buceros bicornis) 60.png': 15,
#  'pred\\Great Hornbill (Buceros bicornis) 73.png': 11,
#  'pred\\Great Hornbill (Buceros bicornis) 77.png': 11,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 186.png': 11,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 187.png': 1,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 208.png': 12,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 211.png': 11,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 215.png': 23,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 230.png': 12,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 237.png': 12,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 5.png': 17,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 51.png': 5,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 59.png': 12,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 69.png': 12,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 8.png': 1,
#  'pred\\Ibisbill Ibidorhyncha struthersii 108.jpg': 13,
#  'pred\\Ibisbill Ibidorhyncha struthersii 112.jpg': 13,
#  'pred\\Ibisbill Ibidorhyncha struthersii 140.jpg': 13,
#  'pred\\Ibisbill Ibidorhyncha struthersii 16.jpg': 13,
#  'pred\\Ibisbill Ibidorhyncha struthersii 27.jpg': 13,
#  'pred\\Ibisbill Ibidorhyncha struthersii 55.jpg': 18,
#  'pred\\Ibisbill Ibidorhyncha struthersii 74.jpg': 13,
#  'pred\\Indian Courser Cursorius coromandelicus 1.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 112.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 155.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 157.png': 0,
#  'pred\\Indian Courser Cursorius coromandelicus 158.png': 1,
#  'pred\\Indian Courser Cursorius coromandelicus 163.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 181.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 188.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 22.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 256.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 85.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 96.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 98.png': 14,
#  'pred\\Indian Grassbird - Graminicola bengalensis 24.png': 15,
#  'pred\\Indian Grassbird - Graminicola bengalensis 39.png': 15,
#  'pred\\Indian Grassbird - Graminicola bengalensis 63.png': 35,
#  'pred\\Indian Grassbird - Graminicola bengalensis 68.png': 10,
#  'pred\\Indian Grassbird - Graminicola bengalensis 91.png': 15,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 15.png': 10,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 172.png': 31,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 200.png': 16,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 23.png': 5,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 243.png': 31,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 251.png': 26,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 31.png': 16,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 41.png': 16,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 77.png': 26,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 85.png': 16,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 89.png': 18,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 96.png': 31,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 99.png': 16,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 112.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 16.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 160.jpg': 7,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 171.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 176.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 191.jpg': 10,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 198.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 203.jpg': 35,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 23.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 85.jpg': 17,
#  'pred\\Northern Pintail Anas acuta 103.png': 18,
#  'pred\\Northern Pintail Anas acuta 12.png': 7,
#  'pred\\Northern Pintail Anas acuta 137.png': 35,
#  'pred\\Northern Pintail Anas acuta 190.png': 15,
#  'pred\\Northern Pintail Anas acuta 2.png': 35,
#  'pred\\Northern Pintail Anas acuta 204.png': 17,
#  'pred\\Northern Pintail Anas acuta 22.png': 10,
#  'pred\\Northern Pintail Anas acuta 28.png': 18,
#  'pred\\Northern Pintail Anas acuta 33.png': 14,
#  'pred\\Northern Pintail Anas acuta 38.png': 18,
#  'pred\\Northern Pintail Anas acuta 71.png': 18,
#  'pred\\Northern Pintail Anas acuta 85.png': 18,
#  'pred\\Painted Stork Mycteria leucocephala 11.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 111.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 141.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 150.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 155.png': 5,
#  'pred\\Painted Stork Mycteria leucocephala 16.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 48.png': 1,
#  'pred\\Painted Stork Mycteria leucocephala 56.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 58.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 85.png': 19,
#  'pred\\Purple Cochoa Cochoa purpurea 14.png': 20,
#  'pred\\Purple Cochoa Cochoa purpurea 47.png': 20,
#  'pred\\Purple Cochoa Cochoa purpurea 48.png': 19,
#  'pred\\Purple Cochoa Cochoa purpurea 9.png': 20,
#  'pred\\Purple Cochoa Cochoa purpurea 94.png': 9,
#  'pred\\Ruby-cheeked Sunbird Anthreptes singalensis 50.png': 24,
#  'pred\\Ruby-cheeked Sunbird Anthreptes singalensis 52.png': 24,
#  'pred\\Ruby-cheeked Sunbird Anthreptes singalensis 55.png': 6,
#  'pred\\Ruby-cheeked Sunbird Anthreptes singalensis 56.png': 6,
#  'pred\\Ruby-cheeked Sunbird Anthreptes singalensis 88.png': 24,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 107.png': 34,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 123.png': 32,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 135.png': 25,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 156.png': 25,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 167.png': 25,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 17.png': 31,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 171.png': 35,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 202.png': 19,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 230.png': 32,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 232.png': 25,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 240.png': 0,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 247.png': 6,
#  'pred\\Saker Falcon Falco cherrug 10.png': 7,
#  'pred\\Saker Falcon Falco cherrug 121.png': 10,
#  'pred\\Saker Falcon Falco cherrug 160.png': 26,
#  'pred\\Saker Falcon Falco cherrug 167.png': 26,
#  'pred\\Saker Falcon Falco cherrug 192.png': 29,
#  'pred\\Saker Falcon Falco cherrug 207.png': 26,
#  'pred\\Saker Falcon Falco cherrug 28.png': 5,
#  'pred\\Saker Falcon Falco cherrug 43.png': 23,
#  'pred\\Saker Falcon Falco cherrug 9.png': 26,
#  'pred\\Saker Falcon Falco cherrug 93.png': 10,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 10.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 12.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 120.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 142.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 147.png': 4,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 163.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 185.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 218.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 223.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 242.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 41.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 55.png': 0,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 84.png': 34,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 105.png': 8,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 110.png': 25,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 168.png': 28,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 173.png': 28,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 179.png': 28,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 204.png': 3,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 207.png': 28,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 46.png': 3,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 86.png': 3,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 90.png': 3,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 116.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 128.png': 31,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 131.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 178.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 183.png': 5,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 189.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 191.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 207.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 22.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 262.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 49.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 55.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 98.png': 5,
#  'pred\\Sultan Tit Melanochlora sultanea 124.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 135.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 140.png': 24,
#  'pred\\Sultan Tit Melanochlora sultanea 187.png': 24,
#  'pred\\Sultan Tit Melanochlora sultanea 200.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 206.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 207.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 219.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 237.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 4.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 43.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 89.png': 30,
#  'pred\\Swamp Francolin Francolinus gularis 104.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 151.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 192.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 201.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 217.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 228.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 239.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 24.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 264.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 292.png': 29,
#  'pred\\Swamp Francolin Francolinus gularis 299.png': 28,
#  'pred\\Swamp Francolin Francolinus gularis 300.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 61.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 83.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 88.png': 31,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 1.png': 8,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 104.png': 37,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 112.png': 32,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 136.png': 15,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 174.png': 26,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 39.png': 25,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 52.png': 8,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 57.png': 32,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 6.png': 25,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 69.png': 32,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 8.png': 4,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 117.png': 34,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 12.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 122.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 151.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 171.png': 25,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 178.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 196.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 2.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 20.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 217.png': 25,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 242.png': 32,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 5.png': 27,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 105.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 113.png': 27,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 12.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 128.png': 15,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 165.png': 8,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 169.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 180.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 23.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 36.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 81.png': 8,
#  'pred\\White-throated Bushchat Saxicola insignis 133.png': 35,
#  'pred\\White-throated Bushchat Saxicola insignis 152.png': 26,
#  'pred\\White-throated Bushchat Saxicola insignis 29.png': 35,
#  'pred\\White-throated Bushchat Saxicola insignis 53.png': 14,
#  'pred\\White-throated Bushchat Saxicola insignis 73.png': 35,
#  'pred\\White-throated Bushchat Saxicola insignis 77.png': 35,
#  'pred\\White-throated Bushchat Saxicola insignis 9.png': 35,
#  'pred\\White-throated Bushchat Saxicola insignis 95.png': 35,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 105.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 129.png': 20,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 133.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 149.png': 26,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 157.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 183.png': 11,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 236.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 25.png': 26,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 26.png': 24,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 50.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 58.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 99.png': 10,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 124.png': 8,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 150.png': 37,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 152.png': 26,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 159.png': 37,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 170.png': 8,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 33.png': 37,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 5.png': 37,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 81.png': 37}

# %%
# Assuming you have the prediction mapping dictionary
prediction_mapping = {
    0: 'Abbott’s Babbler Malacocincla abbotti = मोटोठूँडे भ्याकुरमोटोठूँडे भ्याकुर',
    1: 'Black Bittern (Dupetor flavicollis) = कालो जूनबकुल्ला',
    2: 'Blue-eared Kingfisher Alcedo meninting = ',
    3: 'Blue-naped Pitta Pitta nipalensis = ',
    4: 'Broad-billed Warbler Tickellia hodgsoni',
    5: 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz',
    6: 'Chestnut Munia Lonchura atricapilla = कोटेरो मुनियाँ',
    7: 'Cinereous Vulture Aegypius monachus = राज गिद्ध',
    8: 'Golden Babbler Stachyris chrysaea = NO Name',
    9: 'Gould’s Shortwing Brachypteryx stellata = थोप्ले लघुपंख',
    10: 'Great Bittern Botaurus stellaris = कालो जूनबकुल्ला',
    11: 'Great Hornbill (Buceros bicornis) = राजधनेश',
    12: 'Great Slaty Woodpecker Mulleripicus pulverulentus',
    13: 'Ibisbill Ibidorhyncha struthersii = तिलहरी चरा',
    14: 'Indian Courser Cursorius coromandelicus = गाजले धावक',
    15: 'Indian Grassbird - Graminicola bengalensis',
    16: 'Indian Nightjar Caprimulgus asiaticus = चुकचुके चैतेचरा',
    17: 'Knob-billed Duck Sarkidiornis melanotos = नकटा',
    18: 'Northern Pintail Anas acuta = सुइरोपुछ्रे',
    19: 'Painted Stork Mycteria leucocephala = लालटाउके गरुड',
    20: 'Purple Cochoa Cochoa purpurea = बैजनी कचोवा',
    21: 'Red-headed Trogon Harpactes erythrocephalus = रक्त्त शिर',
    22: 'Red-headed Vulture Sarcogyps calvus = सुन गिद्ध',
    23: 'Red-necked Falcon Falco chicquera = रातोटाउके बौँडाइ',
    24: 'Ruby-cheeked Sunbird Anthreptes singalensis = प्याजीकाने बुङ्गेचरा',
    25: 'Rusty-fronted Barwing Actinodura egertoni = कैलोतालु वनचाहर',
    26: 'Saker Falcon Falco cherrug = तोप बाज',
    27: 'Silver-eared Mesia Leiothrix argentauris = चाँदीकाने मिसीया',
    28: 'Slaty-legged Crake Rallina eurizonoides = देउकौवा',
    29: 'Spot-bellied Eagle Owl Bubo nipalensis = महाकौशिक',
    30: 'Sultan Tit Melanochlora sultanea = स्वर्णचूल राजचिचिल्कोटे',
    31: 'Swamp Francolin Francolinus gularis = सिमतित्रा',
    32: 'Tawny-bellied Babbler Dumetia hyperythra = कैलो घाँसेभ्याकुर',
    33: 'Thick-billed Green Pigeon Treron curvirostra = मोटोठूँडे हलेसो',
    34: 'White-throated Bulbul Alophoixus flaveolus =  सेतोकण्ठे जुरेली',
    35: 'White-throated Bushchat Saxicola insignis = सेतोकण्ठे धिप्सी',
    36: 'Yellow-rumped Honeyguide - Indicator xanthonotus = पीतनिर्गम फिस्टो',
    37: 'Yellow-vented Warbler Phylloscopus cantator = मोटोठूँडे भ्याकुर'
}

# Map predicted labels to names using prediction_mapping dictionary
predicted_names = [prediction_mapping[label] for label in pred_dict.values()]

# Print or use the predicted names
print(predicted_names)
# Out:
# ['Abbott’s Babbler Malacocincla abbotti = मोटोठूँडे भ्याकुरमोटोठूँडे भ्याकुर', 'Abbott’s Babbler Malacocincla abbotti = मोटोठूँडे भ्याकुरमोटोठूँडे भ्याकुर', 'Abbott’s Babbler Malacocincla abbotti = मोटोठूँडे भ्याकुरमोटोठूँडे भ्याकुर', 'Abbott’s Babbler Malacocincla abbotti = मोटोठूँडे भ्याकुरमोटोठूँडे भ्याकुर', 'Abbott’s Babbler Malacocincla abbotti = मोटोठूँडे भ्याकुरमोटोठूँडे भ्याकुर', 'Abbott’s Babbler Malacocincla abbotti = मोटोठूँडे भ्याकुरमोटोठूँडे भ्याकुर', 'Abbott’s Babbler Malacocincla abbotti = मोटोठूँडे भ्याकुरमोटोठूँडे भ्याकुर', 'Abbott’s Babbler Malacocincla abbotti = मोटोठूँडे भ्याकुरमोटोठूँडे भ्याकुर', 'White-throated Bushchat Saxicola insignis = सेतोकण्ठे धिप्सी', 'Great Bittern Botaurus stellaris = कालो जूनबकुल्ला', 'Black Bittern (Dupetor flavicollis) = कालो जूनबकुल्ला', 'Black Bittern (Dupetor flavicollis) = कालो जूनबकुल्ला', 'Black Bittern (Dupetor flavicollis) = कालो जूनबकुल्ला', 'Painted Stork Mycteria leucocephala = लालटाउके गरुड', 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz', 'Spot-bellied Eagle Owl Bubo nipalensis = महाकौशिक', 'Swamp Francolin Francolinus gularis = सिमतित्रा', 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz', 'Rusty-fronted Barwing Actinodura egertoni = कैलोतालु वनचाहर', 'Black Bittern (Dupetor flavicollis) = कालो जूनबकुल्ला', 'Blue-eared Kingfisher Alcedo meninting = ', 'Ruby-cheeked Sunbird Anthreptes singalensis = प्याजीकाने बुङ्गेचरा', 'Great Bittern Botaurus stellaris = कालो जूनबकुल्ला', 'Blue-eared Kingfisher Alcedo meninting = ', 'Blue-eared Kingfisher Alcedo meninting = ', 'Blue-eared Kingfisher Alcedo meninting = ', 'Ruby-cheeked Sunbird Anthreptes singalensis = प्याजीकाने बुङ्गेचरा', 'Blue-eared Kingfisher Alcedo meninting = ', 'Blue-eared Kingfisher Alcedo meninting = ', 'Blue-eared Kingfisher Alcedo meninting = ', 'Blue-eared Kingfisher Alcedo meninting = ', 'Blue-naped Pitta Pitta nipalensis = ', 'Thick-billed Green Pigeon Treron curvirostra = मोटोठूँडे हलेसो', 'Abbott’s Babbler Malacocincla abbotti = मोटोठूँडे भ्याकुरमोटोठूँडे भ्याकुर', 'Blue-naped Pitta Pitta nipalensis = ', 'Blue-naped Pitta Pitta nipalensis = ', 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz', 'Blue-naped Pitta Pitta nipalensis = ', 'Blue-naped Pitta Pitta nipalensis = ', 'Blue-naped Pitta Pitta nipalensis = ', 'Broad-billed Warbler Tickellia hodgsoni', 'Broad-billed Warbler Tickellia hodgsoni', 'Broad-billed Warbler Tickellia hodgsoni', 'Broad-billed Warbler Tickellia hodgsoni', 'Broad-billed Warbler Tickellia hodgsoni', 'Red-necked Falcon Falco chicquera = रातोटाउके बौँडाइ', 'Broad-billed Warbler Tickellia hodgsoni', 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz', 'Swamp Francolin Francolinus gularis = सिमतित्रा', 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz', 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz', 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz', 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz', 'Rusty-fronted Barwing Actinodura egertoni = कैलोतालु वनचाहर', 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz', 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz', 'Swamp Francolin Francolinus gularis = सिमतित्रा', 'Chestnut Munia Lonchura atricapilla = कोटेरो मुनियाँ', 'Chestnut Munia Lonchura atricapilla = कोटेरो मुनियाँ', 'Cheer Pheasant (Catreus wallichii) = Cheer Kaliz', 'Great Bittern Botaurus stellaris = कालो जूनबकुल्ला', 'Chestnut Munia Lonchura atricapilla = कोटेरो मुनियाँ', 'Chestnut Munia Lonchura atricapilla = कोटेरो मुनियाँ', 'White-throated Bulbul Alophoixus flaveolus =  सेतोकण्ठे जुरेली', 'Chestnut Munia Lonchura atricapilla = कोटेरो मुनियाँ', 'Chestnut Munia Lonchura atricapilla = कोटेरो मुनियाँ', 'Chestnut Munia Lonchura atricapilla = कोटेरो मुनियाँ', 'Chestnut Munia Lonchura atricapilla = कोटेरो मुनियाँ', 'Chestnut Munia Lonchura atricapilla = कोटेरो मुनियाँ', 'Cinereous Vulture Aegypius monachus = राज गिद्ध', 'Cinereous Vulture Aegypius monachus = राज गिद्ध', 'Gould’s Shortwing Brachypteryx stellata = थोप्ले लघुपंख', 'Cinereous Vulture Aegypius monac ...

# %%
pred_dict
# Out:
# {'pred\\Abbott’s Babbler Malacocincla abbotti 106.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 136.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 140.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 21.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 36.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 51.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 8.jpg': 0,
#  'pred\\Abbott’s Babbler Malacocincla abbotti 95.jpg': 0,
#  'pred\\Black Bittern (Dupetor flavicollis) 11.png': 35,
#  'pred\\Black Bittern (Dupetor flavicollis) 12.png': 10,
#  'pred\\Black Bittern (Dupetor flavicollis) 14.png': 1,
#  'pred\\Black Bittern (Dupetor flavicollis) 152.png': 1,
#  'pred\\Black Bittern (Dupetor flavicollis) 159.png': 1,
#  'pred\\Black Bittern (Dupetor flavicollis) 184.png': 19,
#  'pred\\Black Bittern (Dupetor flavicollis) 199.png': 5,
#  'pred\\Black Bittern (Dupetor flavicollis) 217.png': 29,
#  'pred\\Black Bittern (Dupetor flavicollis) 226.png': 31,
#  'pred\\Black Bittern (Dupetor flavicollis) 246.png': 5,
#  'pred\\Black Bittern (Dupetor flavicollis) 250.png': 25,
#  'pred\\Black Bittern (Dupetor flavicollis) 80.png': 1,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 11.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 113.png': 24,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 123.png': 10,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 137.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 158.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 161.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 184.png': 24,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 28.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 34.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 55.png': 2,
#  'pred\\Blue-eared Kingfisher Alcedo meninting 68.png': 2,
#  'pred\\Blue-naped Pitta Pitta nipalensis 149.png': 3,
#  'pred\\Blue-naped Pitta Pitta nipalensis 158.png': 33,
#  'pred\\Blue-naped Pitta Pitta nipalensis 161.png': 0,
#  'pred\\Blue-naped Pitta Pitta nipalensis 174.png': 3,
#  'pred\\Blue-naped Pitta Pitta nipalensis 176.png': 3,
#  'pred\\Blue-naped Pitta Pitta nipalensis 177.png': 5,
#  'pred\\Blue-naped Pitta Pitta nipalensis 21.png': 3,
#  'pred\\Blue-naped Pitta Pitta nipalensis 77.png': 3,
#  'pred\\Blue-naped Pitta Pitta nipalensis 79.png': 3,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 136.png': 4,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 17.png': 4,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 2.png': 4,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 36.png': 4,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 57.png': 4,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 83.png': 23,
#  'pred\\Broad-billed Warbler Tickellia hodgsoni 84.png': 4,
#  'pred\\Cheer Pheasant (Catreus wallichii) 122.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 132.png': 31,
#  'pred\\Cheer Pheasant (Catreus wallichii) 140.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 153.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 172.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 182.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 28.png': 25,
#  'pred\\Cheer Pheasant (Catreus wallichii) 29.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 37.png': 5,
#  'pred\\Cheer Pheasant (Catreus wallichii) 44.png': 31,
#  'pred\\Chestnut Munia Lonchura atricapilla 140.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 145.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 150.png': 5,
#  'pred\\Chestnut Munia Lonchura atricapilla 166.png': 10,
#  'pred\\Chestnut Munia Lonchura atricapilla 179.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 182.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 222.png': 34,
#  'pred\\Chestnut Munia Lonchura atricapilla 27.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 46.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 59.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 6.png': 6,
#  'pred\\Chestnut Munia Lonchura atricapilla 71.png': 6,
#  'pred\\Cinereous Vulture Aegypius monachus 1.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 105.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 114.png': 9,
#  'pred\\Cinereous Vulture Aegypius monachus 136.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 171.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 195.png': 5,
#  'pred\\Cinereous Vulture Aegypius monachus 210.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 215.png': 7,
#  'pred\\Cinereous Vulture Aegypius monachus 234.png': 23,
#  'pred\\Cinereous Vulture Aegypius monachus 245.png': 22,
#  'pred\\Cinereous Vulture Aegypius monachus 39.png': 31,
#  'pred\\Cinereous Vulture Aegypius monachus 94.png': 7,
#  'pred\\Golden Babbler Stachyris chrysaea 125.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 153.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 164.png': 3,
#  'pred\\Golden Babbler Stachyris chrysaea 191.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 195.png': 0,
#  'pred\\Golden Babbler Stachyris chrysaea 197.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 22.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 86.png': 37,
#  'pred\\Golden Babbler Stachyris chrysaea 93.png': 8,
#  'pred\\Golden Babbler Stachyris chrysaea 98.png': 8,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 106.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 146.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 162.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 35.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 54.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 60.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 62.png': 9,
#  'pred\\Gould’s Shortwing Brachypteryx stellata 67.png': 9,
#  'pred\\Great Bittern Botaurus stellaris 102.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 110.png': 0,
#  'pred\\Great Bittern Botaurus stellaris 117.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 157.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 164.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 17.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 172.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 18.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 189.png': 10,
#  'pred\\Great Bittern Botaurus stellaris 203.png': 5,
#  'pred\\Great Bittern Botaurus stellaris 30.png': 1,
#  'pred\\Great Bittern Botaurus stellaris 49.png': 10,
#  'pred\\Great Hornbill (Buceros bicornis) 152.png': 11,
#  'pred\\Great Hornbill (Buceros bicornis) 158.png': 19,
#  'pred\\Great Hornbill (Buceros bicornis) 185.png': 11,
#  'pred\\Great Hornbill (Buceros bicornis) 30.png': 11,
#  'pred\\Great Hornbill (Buceros bicornis) 47.png': 19,
#  'pred\\Great Hornbill (Buceros bicornis) 50.png': 5,
#  'pred\\Great Hornbill (Buceros bicornis) 54.png': 19,
#  'pred\\Great Hornbill (Buceros bicornis) 60.png': 15,
#  'pred\\Great Hornbill (Buceros bicornis) 73.png': 11,
#  'pred\\Great Hornbill (Buceros bicornis) 77.png': 11,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 186.png': 11,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 187.png': 1,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 208.png': 12,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 211.png': 11,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 215.png': 23,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 230.png': 12,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 237.png': 12,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 5.png': 17,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 51.png': 5,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 59.png': 12,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 69.png': 12,
#  'pred\\Great Slaty Woodpecker Mulleripicus pulverulentus 8.png': 1,
#  'pred\\Ibisbill Ibidorhyncha struthersii 108.jpg': 13,
#  'pred\\Ibisbill Ibidorhyncha struthersii 112.jpg': 13,
#  'pred\\Ibisbill Ibidorhyncha struthersii 140.jpg': 13,
#  'pred\\Ibisbill Ibidorhyncha struthersii 16.jpg': 13,
#  'pred\\Ibisbill Ibidorhyncha struthersii 27.jpg': 13,
#  'pred\\Ibisbill Ibidorhyncha struthersii 55.jpg': 18,
#  'pred\\Ibisbill Ibidorhyncha struthersii 74.jpg': 13,
#  'pred\\Indian Courser Cursorius coromandelicus 1.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 112.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 155.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 157.png': 0,
#  'pred\\Indian Courser Cursorius coromandelicus 158.png': 1,
#  'pred\\Indian Courser Cursorius coromandelicus 163.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 181.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 188.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 22.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 256.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 85.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 96.png': 14,
#  'pred\\Indian Courser Cursorius coromandelicus 98.png': 14,
#  'pred\\Indian Grassbird - Graminicola bengalensis 24.png': 15,
#  'pred\\Indian Grassbird - Graminicola bengalensis 39.png': 15,
#  'pred\\Indian Grassbird - Graminicola bengalensis 63.png': 35,
#  'pred\\Indian Grassbird - Graminicola bengalensis 68.png': 10,
#  'pred\\Indian Grassbird - Graminicola bengalensis 91.png': 15,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 15.png': 10,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 172.png': 31,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 200.png': 16,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 23.png': 5,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 243.png': 31,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 251.png': 26,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 31.png': 16,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 41.png': 16,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 77.png': 26,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 85.png': 16,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 89.png': 18,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 96.png': 31,
#  'pred\\Indian Nightjar Caprimulgus asiaticus 99.png': 16,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 112.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 16.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 160.jpg': 7,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 171.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 176.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 191.jpg': 10,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 198.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 203.jpg': 35,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 23.jpg': 17,
#  'pred\\Knob-billed Duck Sarkidiornis melanotos 85.jpg': 17,
#  'pred\\Northern Pintail Anas acuta 103.png': 18,
#  'pred\\Northern Pintail Anas acuta 12.png': 7,
#  'pred\\Northern Pintail Anas acuta 137.png': 35,
#  'pred\\Northern Pintail Anas acuta 190.png': 15,
#  'pred\\Northern Pintail Anas acuta 2.png': 35,
#  'pred\\Northern Pintail Anas acuta 204.png': 17,
#  'pred\\Northern Pintail Anas acuta 22.png': 10,
#  'pred\\Northern Pintail Anas acuta 28.png': 18,
#  'pred\\Northern Pintail Anas acuta 33.png': 14,
#  'pred\\Northern Pintail Anas acuta 38.png': 18,
#  'pred\\Northern Pintail Anas acuta 71.png': 18,
#  'pred\\Northern Pintail Anas acuta 85.png': 18,
#  'pred\\Painted Stork Mycteria leucocephala 11.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 111.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 141.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 150.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 155.png': 5,
#  'pred\\Painted Stork Mycteria leucocephala 16.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 48.png': 1,
#  'pred\\Painted Stork Mycteria leucocephala 56.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 58.png': 19,
#  'pred\\Painted Stork Mycteria leucocephala 85.png': 19,
#  'pred\\Purple Cochoa Cochoa purpurea 14.png': 20,
#  'pred\\Purple Cochoa Cochoa purpurea 47.png': 20,
#  'pred\\Purple Cochoa Cochoa purpurea 48.png': 19,
#  'pred\\Purple Cochoa Cochoa purpurea 9.png': 20,
#  'pred\\Purple Cochoa Cochoa purpurea 94.png': 9,
#  'pred\\Red-headed Trogon Harpactes erythrocephalus 104.png': 21,
#  'pred\\Red-headed Trogon Harpactes erythrocephalus 119.png': 21,
#  'pred\\Red-headed Trogon Harpactes erythrocephalus 126.png': 21,
#  'pred\\Red-headed Trogon Harpactes erythrocephalus 150.png': 21,
#  'pred\\Red-headed Trogon Harpactes erythrocephalus 18.png': 12,
#  'pred\\Red-headed Trogon Harpactes erythrocephalus 213.png': 21,
#  'pred\\Red-headed Trogon Harpactes erythrocephalus 217.png': 21,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 135.png': 25,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 156.png': 25,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 167.png': 25,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 17.png': 31,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 171.png': 35,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 202.png': 19,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 230.png': 32,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 232.png': 25,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 240.png': 0,
#  'pred\\Rusty-fronted Barwing Actinodura egertoni 247.png': 6,
#  'pred\\Saker Falcon Falco cherrug 10.png': 7,
#  'pred\\Saker Falcon Falco cherrug 121.png': 10,
#  'pred\\Saker Falcon Falco cherrug 160.png': 26,
#  'pred\\Saker Falcon Falco cherrug 167.png': 26,
#  'pred\\Saker Falcon Falco cherrug 192.png': 29,
#  'pred\\Saker Falcon Falco cherrug 207.png': 26,
#  'pred\\Saker Falcon Falco cherrug 28.png': 5,
#  'pred\\Saker Falcon Falco cherrug 43.png': 23,
#  'pred\\Saker Falcon Falco cherrug 9.png': 26,
#  'pred\\Saker Falcon Falco cherrug 93.png': 10,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 10.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 12.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 120.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 142.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 147.png': 4,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 163.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 185.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 218.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 223.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 242.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 41.png': 27,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 55.png': 0,
#  'pred\\Silver-eared Mesia Leiothrix argentauris 84.png': 34,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 105.png': 8,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 110.png': 25,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 168.png': 28,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 173.png': 28,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 179.png': 28,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 204.png': 3,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 207.png': 28,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 46.png': 3,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 86.png': 3,
#  'pred\\Slaty-legged Crake Rallina eurizonoides 90.png': 3,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 116.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 128.png': 31,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 131.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 178.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 183.png': 5,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 189.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 191.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 207.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 22.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 262.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 49.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 55.png': 29,
#  'pred\\Spot-bellied Eagle Owl Bubo nipalensis 98.png': 5,
#  'pred\\Sultan Tit Melanochlora sultanea 124.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 135.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 140.png': 24,
#  'pred\\Sultan Tit Melanochlora sultanea 187.png': 24,
#  'pred\\Sultan Tit Melanochlora sultanea 200.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 206.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 207.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 219.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 237.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 4.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 43.png': 30,
#  'pred\\Sultan Tit Melanochlora sultanea 89.png': 30,
#  'pred\\Swamp Francolin Francolinus gularis 104.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 151.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 192.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 201.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 217.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 228.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 239.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 24.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 264.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 292.png': 29,
#  'pred\\Swamp Francolin Francolinus gularis 299.png': 28,
#  'pred\\Swamp Francolin Francolinus gularis 300.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 61.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 83.png': 31,
#  'pred\\Swamp Francolin Francolinus gularis 88.png': 31,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 1.png': 8,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 104.png': 37,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 112.png': 32,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 136.png': 15,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 174.png': 26,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 39.png': 25,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 52.png': 8,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 57.png': 32,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 6.png': 25,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 69.png': 32,
#  'pred\\Tawny-bellied Babbler Dumetia hyperythra 8.png': 4,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 117.png': 34,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 12.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 122.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 151.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 171.png': 25,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 178.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 196.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 2.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 20.png': 33,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 217.png': 25,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 242.png': 32,
#  'pred\\Thick-billed Green Pigeon Treron curvirostra 5.png': 27,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 105.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 113.png': 27,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 12.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 128.png': 15,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 165.png': 8,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 169.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 180.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 23.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 36.png': 34,
#  'pred\\White-throated Bulbul Alophoixus flaveolus 81.png': 8,
#  'pred\\White-throated Bushchat Saxicola insignis 133.png': 35,
#  'pred\\White-throated Bushchat Saxicola insignis 152.png': 26,
#  'pred\\White-throated Bushchat Saxicola insignis 29.png': 35,
#  'pred\\White-throated Bushchat Saxicola insignis 53.png': 14,
#  'pred\\White-throated Bushchat Saxicola insignis 73.png': 35,
#  'pred\\White-throated Bushchat Saxicola insignis 77.png': 35,
#  'pred\\White-throated Bushchat Saxicola insignis 9.png': 35,
#  'pred\\White-throated Bushchat Saxicola insignis 95.png': 35,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 105.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 129.png': 20,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 133.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 149.png': 26,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 157.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 183.png': 11,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 236.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 25.png': 26,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 26.png': 24,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 50.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 58.png': 36,
#  'pred\\Yellow-rumped Honeyguide - Indicator xanthonotus 99.png': 10,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 124.png': 8,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 150.png': 37,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 152.png': 26,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 159.png': 37,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 170.png': 8,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 33.png': 37,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 5.png': 37,
#  'pred\\Yellow-vented Warbler Phylloscopus cantator 81.png': 37}

# %%
test_path = '/Users/risal/My_Codes/Projectdataminor/traintestsplit/DataSet/test'

test_loader=DataLoader(
    torchvision.datasets.ImageFolder(test_path,transform=trnsfrm),
    batch_size=64, shuffle=True
)

# %%
from torchmetrics import ConfusionMatrix
import matplotlib.pyplot as plt
import seaborn as sns

# Instantiate metrics
confusion_matrix = ConfusionMatrix(num_classes=38, task="multiclass").to(device)

# Iterate through validation dataset
for images, labels in test_loader:
    images = images.to(device)
    labels = labels.to(device)

    # Forward pass
    with torch.no_grad():
        outputs = mdl(images)

    # Compute predictions
    _, preds = torch.max(outputs, dim=1)

    # Update confusion matrix
    confusion_matrix.update(preds, labels)

# Compute confusion matrix
cm = confusion_matrix.compute()

# Move the confusion matrix to CPU before converting to NumPy
cm = cm.cpu().numpy()

print(f"Confusion Matrix:\n{cm}")
# Out:
# Confusion Matrix:
# [[8 0 0 ... 0 0 0]
#  [0 4 0 ... 1 0 0]
#  [0 0 8 ... 0 0 0]
#  ...
#  [0 0 0 ... 6 0 0]
#  [0 0 0 ... 0 6 0]
#  [0 0 0 ... 0 0 5]]

# %%
# Get class names
class_names = list(labels.cpu().numpy())

# Plot confusion matrix for each class
num_classes = len(class_names)
fig, axes = plt.subplots(nrows=int(np.ceil(num_classes/5)), ncols=5, figsize=(15, 3*num_classes//5))
fig.suptitle('Confusion Matrices for Each Class')

for i, class_name in enumerate(class_names):
    row = i // 5
    col = i % 5
    sns.heatmap(cm[:, i, np.newaxis], annot=True, fmt='d', cmap='Blues', cbar=False, ax=axes[row, col])
    axes[row, col].set_title(f'Class: {class_name}')

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %%
import torch

# Assuming confusion_matrix is the tensor containing the confusion matrix
# Convert the confusion matrix tensor to a numpy array for easier manipulation
confusion_matrix_tensor = confusion_matrix.compute().cpu()

confusion_matrix_np = confusion_matrix_tensor.numpy()

# Calculate True Positives (TP), True Negatives (TN), False Positives (FP), and False Negatives (FN)
TP = np.diag(confusion_matrix_np).sum()
FP = np.sum(confusion_matrix_np, axis=0) - np.diag(confusion_matrix_np)
FN = np.sum(confusion_matrix_np, axis=1) - np.diag(confusion_matrix_np)
TN = np.sum(confusion_matrix_np) - (TP + FP + FN)

# Calculate accuracy and precision
accuracy = (TP + TN) / (TP + TN + FP + FN)
precision = TP / (TP + FP)
recall = TP/(TP +FN)
F1_SCORE = (int(2)*precision * recall)/(precision + recall)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'F1_score: {F1_SCORE}')
# Out:
# Accuracy: [0.98507463 0.96766169 0.99253731 0.9800995  0.99253731 0.95771144
#  0.98507463 0.97263682 0.97512438 0.99253731 0.96766169 0.9800995
#  0.9800995  0.99751244 0.99004975 0.98507463 0.9800995  0.98507463
#  0.97761194 0.9800995  0.99253731 0.99502488 0.98507463 0.98756219
#  0.98258706 0.96268657 0.96766169 0.98756219 0.98258706 0.98507463
#  0.99502488 0.97263682 0.97263682 0.98258706 0.9800995  0.9800995
#  0.98507463 0.98756219]
# Precision: [0.97769517 0.98134328 1.         0.98134328 0.99245283 0.94945848
#  0.9887218  0.97769517 0.97407407 0.9887218  0.96336996 0.9887218
#  0.99621212 1.         0.99245283 0.98501873 1.         0.9887218
#  0.99245283 0.97769517 0.99621212 1.         0.99621212 0.98501873
#  0.98134328 0.97407407 0.97407407 0.99245283 0.99621212 0.9887218
#  1.         0.96691176 0.9887218  0.99245283 0.98501873 0.97769517
#  1.         0.99245283]
# F1_score: [0.9887218  0.97588126 0.99432892 0.98501873 0.99432892 0.96869245
#  0.9887218  0.97951583 0.98134328 0.99432892 0.97588126 0.98501873
#  0.98501873 0.99810247 0.99245283 0.9887218  0.98501873 0.9887218
#  0.98317757 0.98501873 0.99432892 0.99621212 0.9887218  0.9905838
#  0.98686679 0.97227357 0.97588126 0.9905838  0.98686679 0.9887218
#  0.99621212 0.97951583 0.97951583 0.98686679 0.98501873 0.98501873
#  0.9887218  0.9905838 ]

# %%
# images_path=glob.glob('/Users/risal/My_Codes/Projectdataminor/traintestsplit/Dataset/newtest/*')# test image
# images_path=glob.glob('/Users/risal/My_Codes/Projectdataminor/traintestsplit/Dataset/train/Golden Babbler Stachyris chrysaea/Golden Babbler Stachyris chrysaea 1.png')# train image
images_path=glob.glob('/Users/risal/My_Codes/Projectdataminor/traintestsplit/Dataset/val/Abbott’s Babbler Malacocincla abbotti/Abbott’s Babbler Malacocincla abbotti 1.jpg')

# %%
import matplotlib.pyplot as plt
# pred_dicto ={}
for i in images_path:
    pred_bird = prediction(i, trnsfrm, mdl, class_labels, device)
    
    # Load the image using PIL
    predicted_labels = [pred_bird ]
    prediction_names= prediction_mapping[pred_bird]
    image = Image.open(i)

    # Plot the image using matplotlib
    plt.imshow(image)
    plt.title(predicted_labels)
    plt.axis('off')  # Turn off axis labels
    plt.show()
    print(prediction_names)
# Out:
# Abbott’s Babbler Malacocincla abbotti = मोटोठूँडे भ्याकुरमोटोठूँडे भ्याकुर
